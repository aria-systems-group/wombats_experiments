# %%
import os
os.chdir(os.path.join('..', '..'))

# %%
from wombats.systems import (StaticMinigridTSWrapper,
                             LavaComparison_noDryingOff)
from wombats.automaton import active_automata
from wombats.automaton import MinigridTransitionSystem
from wombats.learning import FlexfringeInterface
from wombats.automaton import Automaton
from wombats.utils import get_experiment_paths

# setting all paths
EXPERIMENT_NAME = 'manipulator'

path_data = get_experiment_paths(EXPERIMENT_NAME)
EXPERIMENT_DIR = path_data['EXPERIMENT_DIR']
TS_MODEL_CONFIG_FILE = path_data['TS_MODEL_CONFIG_FILE']
DFA_MODEL_CONFIG_FILE = path_data['DFA_MODEL_CONFIG_FILE']
LEARNER_DATA_DIR = path_data['LEARNER_DATA_DIR']
LEARNING_TRAIN_DATA_REL_FILEPATH = path_data['LEARNING_TRAIN_DATA_REL_FILEPATH']

# reset the kernel's Automata class' experimental directory for all created
# Automaton objects.
#
# If you autoreload any code having to do with the automaton, then you will
# need to re-run this cell to get the right automaton data path back, as the
# reload will reset the base Automaton class' automata_data_dir property
Automaton.automata_data_dir = os.path.join(EXPERIMENT_DIR)

# %% [markdown]
# # Load the Transition System which Peter manually created

# %%
from wombats.automaton import active_automata

transition_system = active_automata.get(
    automaton_type='TS',                                
    graph_data=TS_MODEL_CONFIG_FILE)

# transition_system.draw('_'.joint([EXPERIMENT_NAME, 'abstraction']))

# %% [markdown]
# # Convert controls  to output_strings & visited_states

# %%
def eval_sampled_traces(traces, record_video=True):
    if traces is None:
        return
    
    output_strings = []
    for controls, length, prob in zip(*traces):
        if controls is None:
            continue
        output_string, _, video_path = minigrid_TS.run(
            controls,
            record_video=record_video,
            overwrite_old_video=record_video)
        output_strings.append(output_string)
        
        if record_video:
            print(pdfa_specification.cross_entropy_approx(output_string))
            print(prob)
            print(length)
        
        if record_video:
            v = Video(video_path, embed=True,
                      html_attributes="controls muted autoplay loop")
            display(v)
        
    return output_strings

# %%
controls = []
controls.append(['m_to_m_eeL2_grp0', 'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL3_grp1', 'h_to_p_eeL3_grp1', 'p_to_m_eeL3_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL1_grp0', 'm_to_g_eeL1_grp0', 'g_to_h_eeL1_grp3', 'h_to_h_eeL0_grp3', 'h_to_h_eeL5_grp3', 'h_to_p_eeL5_grp3', 'p_to_m_eeL5_grp0'])
controls.append(['m_to_m_eeL2_grp0', 'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL3_grp1', 'h_to_p_eeL3_grp1', 'p_to_m_eeL3_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_ee
grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL2_grp0', 'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL4_grp1', 'h_to_p_eeL4_grp1', 'p_to_m_eeL4_grp0', 'm_to_m_eeL0_grp0',  'm_to_m_eeL1_grp0',  'm_to_g_eeL1_grp0',  'g_to_h_eeL1_grp3',  'h_to_h_eeL0_grp3',  'h_to_h_eeL5_grp3',  'h_to_p_eeL5_grp3',  'p_to_m_eeL5_grp0'])

controls.append(['m_to_m_eeL2_grp0', 'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL3_grp1', 'h_to_p_eeL3_grp1', 'p_to_m_eeL3_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL4_grp0',  'm_to_g_eeL4_grp0', 'g_to_h_eeL4_grp2', 'h_to_h_eeL0_grp2', 'h_to_h_eeL2_grp2', 'h_to_p_eeL2_grp2', 'p_to_m_eeL2_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL3_grp0', 'm_to_g_eeL3_grp0', 'g_to_h_eeL3_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL4_grp1', 'h_to_p_eeL4_grp1', 'p_to_m_eeL4_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL2_grp0',  'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp2', 'h_to_h_eeL0_grp2', 'h_to_h_eeL3_grp2', 'h_to_p_eeL3_grp2', 'p_to_m_eeL3_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL1_grp0', 'm_to_g_eeL1_grp0',  'g_to_h_eeL1_grp3', 'h_to_h_eeL0_grp3', 'h_to_h_eeL5_grp3', 'h_to_p_eeL5_grp3', 'p_to_m_eeL5_grp0'])

# %%
output_strings = []
for control in controls:
    output_string, visited_states = transition_system.run(control)

    output_strings.append(output_string)
    print(f'Output word of run: {output_string}')
    print(f'Output state sequence of run: {visited_states}')
# Out:
# Output word of run: ['P02P14P21', 'P02P14P21', 'P02P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P25']
# Output state sequence of run: ['m_0_0_2_4_1_', 'm_2_0_2_4_1_', 'g_2_0_2_4_1_', 'h_2_1_0_4_1_', 'h_0_1_0_4_1_', 'h_3_1_0_4_1_', 'p_3_1_0_4_1_', 'm_3_0_3_4_1_', 'm_0_0_3_4_1_', 'm_1_0_3_4_1_', 'g_1_0_3_4_1_', 'h_1_3_3_4_0_', 'h_0_3_3_4_0_', 'h_5_3_3_4_0_', 'p_5_3_3_4_0_', 'm_5_0_3_4_5_']
# Output word of run: ['P02P14P21', 'P02P14P21', 'P02P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P25']
# ...

# %% [markdown]
# # Load a Safety DFA

# %%
safe_specification = active_automata.get(automaton_type='DFA',
                                         graph_data=DFA_MODEL_CONFIG_FILE)
safe_specification.draw('_'.join([EXPERIMENT_NAME, 'SafetyDFA']))

# %% [markdown]
# # Let's infer a PDFA from the demonstrations!

# %%
traces = output_strings

train_data_file = transition_system.write_traces_to_file(
    traces,
    alphabet_size=transition_system.alphabet_size,
    file=LEARNING_TRAIN_DATA_REL_FILEPATH)

# %% [markdown]
# ### Learning with `Flexfringe`

# %%
flexfringe = FlexfringeInterface(output_directory=LEARNER_DATA_DIR)
flexfringe.infer_model(get_help=True)
# Out:
# no learning options specified, printing tool help:
# welcome, running git commit c8fad5bd3b0c0dad0e28ec7606f20a7fcf975071 with: dfasat/flexfringe --help
# Usage: flexfringe [OPTIONS]* [input dfa file]
#       --version                          Display version information
#   -V, --debug=integer                    Debug mode and verbosity evel
#   -o, --output-dir=string                Relative path for output files with
#                                          trailing /, default: "./".
#   -h, --heuristic-name=string            Name of the merge heurstic to use;
#                                          default count_driven. Use any
#                                          heuristic in the evaluation
#                                          directory. It is often beneficial to
#                                          write your own, as heuristics are
#                                          very application specific.
# ...

# %%
flexfringe.infer_model(training_file=train_data_file,
                       h='kldistance',
                       d='kl_data',
                       n='1',
                       x='0',
                       w='0',
                       a='0',
                       b='1',
                       f='1',
                       I='0',
                       t='1',
                       l='0',
                       q='0',
                       y='0',
                       p='5')

# flexfringe.draw_initial_model()
flexfringe.draw_learned_model()
# Out:
# welcome, running git commit c8fad5bd3b0c0dad0e28ec7606f20a7fcf975071 with: dfasat/flexfringe -h=kldistance -d=kl_data -n=1 -x=0 -w=0 -a=0 -b=1 -f=1 -I=0 -t=1 -l=0 -q=0 -y=0 -p=5 --output-dir=experiments/manipulator/flexfringe_data/dfa /Users/kandai/Documents/projects/research/wombats_experiments/experiments/manipulator/flexfringe_data/manipulator_train
# valid: kldistance
# aic 1
# alergia 1
# alergia94 1
# conflict_driven 1
# conflict_edsm_driven 1
# conflict_overlap_driven 1
# count_driven 1
# depth_driven 1
# evidence_driven 1
# fixed_depth_mse_error 1
# full_overlap_driven 1
# kldistance 1
# likelihoodratio 1
# mealy 1
# mse_error 1
# overlap4logs 1
# overlap_driven 1
# process_mining 1
# Using heuristic kldistance
# Creating apta using evaluation class kl_data
# batch mode selected
# reading data finished, processing:
# dfasat running
# blue: 1 , red: 1
# m99689 blue: 2 , red: 1
# m99682 blue: 2 , red: 1
# No Merge was successful
# m99698 blue: 2 , red: 1
# ...

# %% [markdown]
# loading into `wombats`:

# %%
learned_fdfa = active_automata.get(automaton_type='FDFA',
                                   graph_data=flexfringe,
                                   graph_data_format='learning_interface')
learned_pdfa = active_automata.get(automaton_type='PDFA',
                                   graph_data=learned_fdfa,
                                   graph_data_format='fdfa_object',
                                   merge_sinks=True)
learned_pdfa.draw('_'.join([EXPERIMENT_NAME, 'learned', 'PDFA']))

# %% [markdown]
# ## Computing the Most-Probable, Possible Controller
#
# We see here that we get good results from this learning process. The learned specification has some limitations, for example in state `q9` it has no self-transition that would allow a robot in a different environment to make a jump of more than one cell from a carpet cell to a goal cell. This is not really a negative thing, as it is just as possible that we intended to inform the robot to only ever jump from a carpet cell to a goal cell if they're one cell apart.

# %%
def solve_environment(specification,
                      show_figures=False):
    
    TS = transition_system
    if show_figures:
        print('environment')
        print('underlying transition system')
        TS.draw('_'.join([EXPERIMENT_NAME, 'TS']))

    product = active_automata.get(automaton_type='Product',
                                  graph_data=(TS, specification))
    if show_figures:
        print('product automaton')
        product.draw('_'.join([EXPERIMENT_NAME, 'learned', 'product']))

    (controls,
     prob_of_controls_under_spec) = product.compute_strategy()

    print(f'Optimal Controls: {controls}')
    print(f'Probability of Generated TS Observations in Spec: ' +
          f'{prob_of_controls_under_spec}')

    (output_string,
     visited_states) = TS.run(controls)
    
    print(output_string)
    print(visited_states)
        
solve_environment(learned_pdfa, show_figures=False)
# Out:
# ...
# Optimal Controls: ['m_to_m_eeL2_grp0', 'm_to_g_eeL2_grp0', 'g_to_h_eeL2_grp1', 'h_to_h_eeL0_grp1', 'h_to_h_eeL3_grp1', 'h_to_p_eeL3_grp1', 'p_to_m_eeL3_grp0', 'm_to_m_eeL0_grp0', 'm_to_m_eeL1_grp0', 'm_to_g_eeL1_grp0', 'g_to_h_eeL1_grp3', 'h_to_h_eeL0_grp3', 'h_to_h_eeL5_grp3', 'h_to_p_eeL5_grp3', 'p_to_m_eeL5_grp0']
# Probability of Generated TS Observations in Spec: 1.2746916995093305e-09
# ['P02P14P21', 'P02P14P21', 'P02P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P00P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P21', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P20', 'P03P14P25']
# ['m_0_0_2_4_1_', 'm_2_0_2_4_1_', 'g_2_0_2_4_1_', 'h_2_1_0_4_1_', 'h_0_1_0_4_1_', 'h_3_1_0_4_1_', 'p_3_1_0_4_1_', 'm_3_0_3_4_1_', 'm_0_0_3_4_1_', 'm_1_0_3_4_1_', 'g_1_0_3_4_1_', 'h_1_3_3_4_0_', 'h_0_3_3_4_0_', 'h_5_3_3_4_0_', 'p_5_3_3_4_0_', 'm_5_0_3_4_5_']
